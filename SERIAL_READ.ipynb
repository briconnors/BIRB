# %%
# import serial

# change this to your actual serial port and baud rate
port = 'COM5'  
baud_rate = 115200  
title=f"small1_8_26"

try:
    ser = serial.Serial(port, baud_rate, timeout=1)
    print(f"Opened serial port: {port} at {baud_rate} baud")

    with open(title, 'w') as f:
        print("logging started. Ctrl+C to stop.")
        while True:
            line = ser.readline().decode('utf-8').strip()
            if line:
                print(line)       # print to console for live view
                f.write(line + '\n')  # save to file
except KeyboardInterrupt:
    print("\nLogging stopped by user.")
except Exception as e:
    print(f"Error: {e}")
finally:
    if 'ser' in locals() and ser.is_open:
        ser.close()
        print("Serial port closed.")
# Out:
# Error: could not open port 'COM5': PermissionError(13, 'Access is denied.', None, 5)

# %%
pip install pyserial

# %%
import pandas as pd

# Load the CSV
df = pd.read_csv('small_8_25.csv',on_bad_lines="skip")

# Save as TXT (default tab-delimited, change sep if needed)
df.to_csv('small_8_25.txt', sep=',', index=False)  # or sep=',' or sep=' ' depending on what you want
df.to_csv('small_8_25.csv', sep='\t', index=False)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv(title, on_bad_lines="skip")
time=df.iloc[:,0].to_numpy()
angle=df.iloc[:,1].to_numpy()
bound=time<50000000
filteredTime=time[bound]
filteredAngle=angle[bound]


plt.figure()
plt.plot(filteredTime,filteredAngle,label='output shaft angle')
plt.xlabel('Time(s)')
plt.ylabel('Angle (deg)')
plt.title('Small Motor Tuning (kp=15, ki=1, kd=0)')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2
